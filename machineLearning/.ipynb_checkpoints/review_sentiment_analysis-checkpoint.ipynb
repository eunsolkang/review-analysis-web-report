# %% [markdown]
# ## Importing Necesseties

# %%
import re
import string
import pandas as pd
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
from nltk.corpus import stopwords

from collections import Counter

from keras.preprocessing.text import Tokenizer

import pickle

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from keras.layers import Embedding, Dense, LSTM
from keras.models import Sequential 
from keras.preprocessing.sequence import pad_sequences
from keras import optimizers
from keras import regularizers
from keras.models import load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# ## Reading the Data

# %%
data = pd.read_csv('../data/review_sentences_with_sentiment.csv')
data.head(5)
# Out:
#                                             sentence sentiment
# 0  It's a pretty good, inexpensive casual or busi...         1
# 1  For example, it has no side pleats in back and...         0
# 2                   If you do you'll be disappointed         2
# 3  This is only noticeable to me and only because...         0
# 4  Also, there are lots of loose threads from pro...         2

# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# ### Cleaning the Corpus

# %%
'''
Make text lowercase, remove text in square brackets, remove links, remove HTML tags,
remove punctuation, remove words containing numbers, remove all single characters, 
and substitute multiple spaces with single space.
'''
def clean_text(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('\n', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text)
    text = re.sub(r'\s+', ' ', text, flags=re.I)
    return text

data['sentence'] = data['sentence'].apply(lambda x:clean_text(x))

# delete row with missing values
data = data.dropna(axis=0)

data.head(5)
# Out:
#                                             sentence sentiment
# 0  its pretty good inexpensive casual or business...         1
# 1  for example it has no side pleats in back and ...         0
# 2                    if you do youll be disappointed         2
# 3  this is only noticeable to me and only because...         0
# 4  also there are lots of loose threads from prod...         2

# %% [markdown]
# ### Lemmatization

# %%
def lemmatize_all(sentence):
    wnl = WordNetLemmatizer()
    for word, tag in pos_tag(word_tokenize(sentence)):
        if tag.startswith("NN"):
            yield wnl.lemmatize(word, pos='n')
        elif tag.startswith('VB'):
            yield wnl.lemmatize(word, pos='v')
        elif tag.startswith('JJ'):
            yield wnl.lemmatize(word, pos='a')
        elif tag.startswith('R'):
            yield wnl.lemmatize(word, pos='r')
        else:
            yield word

# %%
data['sentence'] = data['sentence'].apply(lambda x:" ".join(lemmatize_all(str(x))))
data.head(5)
# Out:
#                                             sentence sentiment
# 0  its pretty good inexpensive casual or business...         1
# 1  for example it have no side pleat in back and ...         0
# 2                      if you do youll be disappoint         2
# 3  this be only noticeable to me and only because...         0
# 4  also there be lot of loose thread from product...         2

# %% [markdown]
# ### Tokenizing Data

# %%
data['x_temp'] = data['sentence'].apply(lambda x:str(x).split())

# %% [markdown]
# ### Removing Stopwords

# %%
top = Counter([item for sublist in data['x_temp'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_09e3c1de_701e_11eb_b6b7_302432b071ffrow0_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow1_col1{
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow2_col1{
#             background-color:  #1c6bb0;
#             color:  #f1f1f1;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow3_col1{
#             background-color:  #4d99ca;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow4_col1{
#             background-color:  #91c3de;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow5_col1{
#             background-color:  #95c5df;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow6_col1{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow7_col1{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow8_col1{
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow9_col1{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow10_col1,#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow11_col1{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow12_col1,#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow13_col1{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow14_col1,#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow15_col1,#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow16_col1{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow17_col1{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow18_col1,#T_09e3c1de_701e_11eb_b6b7_302432b071ffrow19_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_09e3c1de_701e_11eb_b6b7_302432b071ff" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow0_col0" class="data row0 col0" >the</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow0_col1" class="data row0 col1" >5742</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow1_col0" class="data row1 col0" >be</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow1_col1" class="data row1 col1" >5598</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow2_col0" class="data row2 col0" >shirt</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow2_col1" class="data row2 col1" >4660</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow3_col0" class="data row3 col0" >and</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow3_col1" class="data row3 col1" >3794</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow4_col0" class="data row4 col0" >fit</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow4_col1" class="data row4 col1" >2922</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow5_col0" class="data row5 col0" >it</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow5_col1" class="data row5 col1" >2870</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow6_col0" class="data row6 col0" >to</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow6_col1" class="data row6 col1" >2183</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow7_col0" class="data row7 col0" >i</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow7_col1" class="data row7 col1" >1857</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow8_col0" class="data row8 col0" >for</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow8_col1" class="data row8 col1" >1833</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow9_col0" class="data row9 col0" >this</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow9_col1" class="data row9 col1" >1761</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow10_col0" class="data row10 col0" >of</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow10_col1" class="data row10 col1" >1340</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow11_col0" class="data row11 col0" >great</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow11_col1" class="data row11 col1" >1335</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow12_col0" class="data row12 col0" >good</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow12_col1" class="data row12 col1" >1295</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow13_col0" class="data row13 col0" >have</td>
#                         <td id="T_09e3c1de_701e_11eb_b6b7_302432b071ffrow13_col1" class="data row13 col1" >1294</td>
#             </tr>
#             <tr>
#                         <th id="T_09e3c1de_701e_11eb_b6b7_302432b071fflevel

# %%
def remove_stopword(x):   
    return [y for y in x if y == 'not' or y not in stopwords.words('english')]

# %%
data['x_temp'] = data['x_temp'].apply(lambda x:remove_stopword(x))
top = Counter([item for sublist in data['x_temp'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
# #T_27749ab1_701e_11eb_ab03_302432b071ffrow0_col1{
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow1_col1{
#             background-color:  #8a86bf;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow2_col1{
#             background-color:  #e2e1ef;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow3_col1{
#             background-color:  #e4e3f0;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow4_col1{
#             background-color:  #e6e5f1;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow5_col1{
#             background-color:  #efedf5;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow6_col1{
#             background-color:  #f1f0f6;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow7_col1{
#             background-color:  #f3f1f7;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow8_col1,#T_27749ab1_701e_11eb_ab03_302432b071ffrow9_col1{
#             background-color:  #f3f2f8;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow10_col1,#T_27749ab1_701e_11eb_ab03_302432b071ffrow11_col1{
#             background-color:  #f6f4f9;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow12_col1{
#             background-color:  #f8f7fa;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow13_col1{
#             background-color:  #faf8fb;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow14_col1{
#             background-color:  #fbfafc;
#             color:  #000000;
#         }#T_27749ab1_701e_11eb_ab03_302432b071ffrow15_col1,#T_27749ab1_701e_11eb_ab03_302432b071ffrow16_col1,#T_27749ab1_701e_11eb_ab03_302432b071ffrow17_col1,#T_27749ab1_701e_11eb_ab03_302432b071ffrow18_col1,#T_27749ab1_701e_11eb_ab03_302432b071ffrow19_col1{
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_27749ab1_701e_11eb_ab03_302432b071ff" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow0_col0" class="data row0 col0" >shirt</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow0_col1" class="data row0 col1" >4660</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow1_col0" class="data row1 col0" >fit</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow1_col1" class="data row1 col1" >2922</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow2_col0" class="data row2 col0" >great</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow2_col1" class="data row2 col1" >1335</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow3_col0" class="data row3 col0" >good</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow3_col1" class="data row3 col1" >1295</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow4_col0" class="data row4 col0" >not</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow4_col1" class="data row4 col1" >1218</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow5_col0" class="data row5 col0" >look</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow5_col1" class="data row5 col1" >1010</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow6_col0" class="data row6 col0" >nice</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow6_col1" class="data row6 col1" >917</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow7_col0" class="data row7 col0" >size</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow7_col1" class="data row7 col1" >848</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow8_col0" class="data row8 col0" >quality</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow8_col1" class="data row8 col1" >832</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow9_col0" class="data row9 col0" >like</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow9_col1" class="data row9 col1" >831</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow10_col0" class="data row10 col0" >buy</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow10_col1" class="data row10 col1" >740</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow11_col0" class="data row11 col0" >well</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow11_col1" class="data row11 col1" >730</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow12_col0" class="data row12 col0" >wear</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow12_col1" class="data row12 col1" >659</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow13_col0" class="data row13 col0" >price</td>
#                         <td id="T_27749ab1_701e_11eb_ab03_302432b071ffrow13_col1" class="data row13 col1" >594</td>
#             </tr>
#             <tr>
#                         <th id="T_27749ab1_701e_11eb_ab03_302432b071fflevel0_row14" class="row_heading level0 row14" >14</th>

# %% [markdown]
# ### One-hot Encoding

# %%
def one_hot(x):
    if x == 0 or x == '0': # neutral or unknown
        x = [1, 0, 0]
    elif x == 1 or x == '1': # positive
        x = [0, 1, 0]
    elif x == 2 or x == '2': # negative
        x = [0, 0, 1]
    else:
        x = None
    return x

# %%
data['y_temp'] = data['sentiment'].apply(lambda x:one_hot(x))

# delete row with poorly classified sentiment
data = data.dropna(axis=0)

data.head(10)
# Out:
#                                             sentence sentiment  \
# 0  its pretty good inexpensive casual or business...         1
# 1  for example it have no side pleat in back and ...         0
# 2                      if you do youll be disappoint         2
# 3  this be only noticeable to me and only because...         0
# 4  also there be lot of loose thread from product...         2
# 5                                       not big deal         0
# 6                                overall solid shirt         1
# 7                                     pardon the pun         0
# 8   and great standby for any traditional guy closet         1
# 9  this be one of van heusens well quality make s...         1
#
#                                               x_temp     y_temp
# 0  [pretty, good, inexpensive, casual, business, ...  [0, 1, 0]
# 1  [example, side, pleat, back, doesnt, box, plea...  [1, 0, 0]
# 2                                [youll, disappoint]  [0, 0, 1]
# 3                    [noticeable, seem, habit, mess]  [1, 0, 0]
# 4  [also, lot, loose, thread, production, arent, ...  [0, 0, 1]
# 5                                   [not, big, deal]  [1, 0, 0]
# 6                            [overall, solid, shirt]  [0, 1, 0]
# 7                                      [pardon, pun]  [1, 0, 0]
# 8         [great, standby, traditional, guy, closet]  [0, 1, 0]
# 9    [one, van, heusens, well, quality, make, shirt]  [0, 1, 0]

# %% [markdown]
# ### Data Splitting

# %%
train_data, test_data = train_test_split(data, train_size = 0.80, random_state = 0)

x_train = train_data['x_temp']
x_test = test_data['x_temp']

y_train = []
y_test = []

for i in range(len(train_data['y_temp'])):
    y_train.append(train_data['y_temp'].iloc[i])
    
for i in range(len(test_data['y_temp'])):
    y_test.append(test_data['y_temp'].iloc[i])
    
y_train = np.array(y_train) 
y_test = np.array(y_test)

# %% [markdown]
# ### Integer Encoding

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train)

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # total word count
rare_cnt = 0 # number of words with frequency of occurrence below the threshold
total_freq = 0 # sum of frequencies of all word in training data
rare_freq = 0 # sum of frequency of words with frequency less than threshold

for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('total word count:',total_cnt)
print('count of rare words with a frequency of %s or less.: %s'%(threshold - 1, rare_cnt))
print("proportion of rare words in a word set:", (rare_cnt / total_cnt)*100)
print("rare word frequency ratio to total frequency of occurrence:", (rare_freq / total_freq)*100)
# Out:
# total word count: 4393
# count of rare words with a frequency of 2 or less.: 2848
# proportion of rare words in a word set: 64.83041201912133
# rare word frequency ratio to total frequency of occurrence: 6.17484741054786

# %%
# remove words with a frequency of 3 or less
# +2 considering padding token 0 and OOV token 1
vocab_size = total_cnt - rare_cnt + 2
print('size of word set:',vocab_size)
# Out:
# size of word set: 1547

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(x_train)
x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)

print(x_train[:3])
print(x_test[:3])
print(len(x_train))
# Out:
# [[30, 3, 17, 486, 2, 1253], [4, 524, 39, 2], [3, 38, 41, 13]]
# [[3, 13, 111], [210, 1214, 212, 3, 2, 1, 1, 621], [5, 10, 264, 1]]
# 12142

# %%
# save tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
drop_train = [index for index, sentence in enumerate(x_train) if len(sentence) < 1]

# remove empty samples
x_train = np.delete(x_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)

print(len(x_train))
print(len(y_train))
# Out:
# 12050
# 12050
# C:\Users\Chorom Ham\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Padding

# %%
train_max_len = max(len(l) for l in x_train)
train_average_len = sum(map(len, x_train))/ len(x_train)
test_max_len = max(len(l) for l in x_test)
test_average_len = sum(map(len, x_test))/ len(x_test)

print("=====Train Data=====")
print("max length: ", train_max_len) 
print("average length: ", train_average_len)
print("\n=====Test Data=====")
print("max length: ", test_max_len) 
print("average length: ", test_average_len)

plt.hist([len(s) for s in x_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# =====Train Data=====
# max length:  53
# average length:  4.541244813278008
#
# =====Test Data=====
# max length:  32
# average length:  4.466732542819499

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s) <= max_len):
            cnt = cnt + 1
    percentage = (cnt / len(nested_list))*100
    print('percentage of examples with length %s or less in the total example: %.3f'
          %(max_len,percentage))

# %%
max_len = 22
below_threshold_len(max_len, x_train)
# Out:
# percentage of examples with length 22 or less in the total example: 99.851

# %%
x_train = pad_sequences(x_train, maxlen=max_len) 
x_test = pad_sequences(x_test, maxlen=max_len)

# %% [markdown]
# ## Model Development

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100)) 
model.add(LSTM(192, kernel_regularizer=regularizers.l2(0.001)))
model.add(Dense(3, activation='softmax'))

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint('review_sentiment_analysis_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
opt = optimizers.RMSprop(lr=0.00001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy']) 
history = model.fit(x_train, y_train, batch_size=10, epochs=200, callbacks=[es, mc], validation_split=0.1)
# Out:
# Epoch 1/200
# 1085/1085 [==============================] - 36s 31ms/step - loss: 1.2416 - accuracy: 0.4393 - val_loss: 1.1504 - val_accuracy: 0.4946
#
# Epoch 00001: val_accuracy improved from -inf to 0.49461, saving model to review_sentiment_analysis_model.h5
# Epoch 2/200
# 1085/1085 [==============================] - 37s 34ms/step - loss: 1.1574 - accuracy: 0.4756 - val_loss: 1.1084 - val_accuracy: 0.4954
#
# Epoch 00002: val_accuracy improved from 0.49461 to 0.49544, saving model to review_sentiment_analysis_model.h5
# Epoch 3/200
# 1085/1085 [==============================] - 36s 33ms/step - loss: 1.1108 - accuracy: 0.4841 - val_loss: 1.0726 - val_accuracy: 0.4954
#
# Epoch 00003: val_accuracy did not improve from 0.49544
# Epoch 4/200
# 1085/1085 [==============================] - 35s 32ms/step - loss: 1.0811 - accuracy: 0.4750 - val_loss: 1.0402 - val_accuracy: 0.4979
#
# Epoch 00004: val_accuracy improved from 0.49544 to 0.49793, saving model to review_sentiment_analysis_model.h5
# Epoch 5/200
# 1085/1085 [==============================] - 41s 38ms/step - loss: 1.0512 - accuracy: 0.4759 - val_loss: 1.0036 - val_accuracy: 0.5087
#
# Epoch 00005: val_accuracy improved from 0.49793 to 0.50871, saving model to review_sentiment_analysis_model.h5
# Epoch 6/200
# 1085/1085 [==============================] - 38s 35ms/step - loss: 1.0063 - accuracy: 0.4986 - val_loss: 0.9691 - val_accuracy: 0.5527
#
# Epoch 00006: val_accuracy improved from 0.50871 to 0.55270, saving model to review_sentiment_analysis_model.h5
# Epoch 7/200
# 1085/1085 [==============================] - 38s 35ms/step - loss: 0.9683 - accuracy: 0.5284 - val_loss: 0.9120 - val_accuracy: 0.5710
#
# Epoch 00007: val_accuracy improved from 0.55270 to 0.57095, saving model to review_sentiment_analysis_model.h5
# Epoch 8/200
# 1085/1085 [==============================] - 28s 26ms/step - loss: 0.9136 - accuracy: 0.5615 - val_loss: 0.8808 - val_accuracy: 0.5784
#
# Epoch 00008: val_accuracy improved from 0.57095 to 0.57842, saving model to review_sentiment_analysis_model.h5
# Epoch 9/200
# 1085/1085 [==============================] - 27s 25ms/step - loss: 0.8780 - accuracy: 0.5895 - val_loss: 0.8674 - val_accuracy: 0.5917
#
# Epoch 00009: val_accuracy improved from 0.57842 to 0.59170, saving model to review_sentiment_analysis_model.h5
# Epoch 10/200
# 1085/1085 [==============================] - 31s 29ms/step - loss: 0.8703 - accuracy: 0.5892 - val_loss: 0.8625 - val_accuracy: 0.6041
#
# Epoch 00010: val_accuracy improved from 0.59170 to 0.60415, saving model to review_sentiment_analysis_model.h5
# Epoch 11/200
# 1085/1085 [==============================] - 30s 28ms/step - loss: 0.8416 - accuracy: 0.6010 - val_loss: 0.8583 - val_accuracy: 0.6149
#
# Epoch 00011: val_accuracy improved from 0.60415 to 0.61494, saving model to review_sentiment_analysis_model.h5
# Epoch 12/200
# 1085/1085 [==============================] - 24s 23ms/step - loss: 0.8475 - accuracy: 0.5952 - val_loss: 0.8580 - val_accuracy: 0.6357
#
# Epoch 00012: val_accuracy improved from 0.61494 to 0.63568, saving model to review_sentiment_analysis_model.h5
# Epoch 13/200
# 1085/1085 [==============================] - 26s 24ms/step - loss: 0.8219 - accuracy: 0.6215 - val_loss: 0.8427 - val_accuracy: 0.6249
#
# Epoch 00013: val_accuracy did not improve from 0.63568
# Epoch 14/200
# 1085/1085 [==============================] - 32s 30ms/step - loss: 0.8183 - accuracy: 0.6192 - val_loss: 0.8380 - val_accuracy: 0.6332
#
# Epoch 00014: val_accuracy did not improve from 0.63568
# Epoch 15/200
# 1085/1085 [==============================] - 26s 24ms/step - loss: 0.8115 - accuracy: 0.6273 - val_loss: 0.8407 - val_accuracy: 0.6166
#
# Epoch 00015: val_accuracy did not improve from 0.63568
# Epoch 16/200
# 1085/1085 [==============================] - 25s 23ms/step - loss: 0.8053 - accuracy: 0.6333 - val_loss: 0.8266 - val_accuracy: 0.6407
#
# Epoch 00016: val_accuracy improved from 0.63568 to 0.64066, saving model to review_sentiment_analysis_model.h5
# Epoch 17/200
# 1085/1085 [==============================] - 29s 27ms/step - loss: 0.8041 - accuracy: 0.6353 - val_loss: 0.8210 - val_accuracy: 0.6340
#
# Epoch 00017: val_accuracy did not improve from 0.64066
# Epoch 18/200
# 1085/1085 [==============================] - 30s 28ms/step - loss: 0.8042 - accuracy: 0.6296 - val_loss: 0.8162 - val_accuracy: 0.6432
#
# Epoch 00018: val_accuracy improved from 0.64066 to 0.64315, saving model to review_sentiment_analysis_model.h5
# Epoch 19/200
# 1085/1085 [==============================] - 24s 22ms/step - loss: 0.7938 - accuracy: 0.6389 - val_loss: 0.8307 - val_accuracy: 0.6174
#
# Epoch 00019: val_accuracy did not improve from 0.64315
# Epoch 20/200
# 1085/1085 [==============================] - 30s 27ms/step - loss: 0.7921 - accuracy: 0.6359 - val_loss: 0.8100 - val_accuracy: 0.6365
#
# Epoch 00020: val_accuracy did not improve from 0.64315
# Epoch 21/200
# 1085/1085 [==============================] - 32s 30ms/step - loss: 0.7841 - accuracy: 0.6511 - val_loss: 0.8108 - val_accuracy: 0.6622
#
# Epoch 00021: val_accuracy improved from 0.64315 to 0.66224, saving model to review_sentiment_analysis_model.h5
# Epoch 22/200
# 1085/1085 [==============================] - 25s 23ms/step - loss: 0.7842 - accuracy: 0.6434 - val_loss: 0.8055 - val_accuracy: 0.6664
#
# Epoch 00022: val_accuracy improved from 0.66224 to 0.66639, saving model to review_sentiment_analysis_model.h5
# Epoch 23/200
# 1085/1085 [==============================] - 26s 24ms/step - loss: 0.7767 - accuracy: 0.6564 - val_loss: 0.7985 - val_accuracy: 0.6390
#
# Epoch 00023: val_accuracy did not improve from 0.66639
# Epoch 24/200
# 1085/1085 [==============================] - 26s 24ms/step - loss: 0.7753 - accuracy: 0.6534 - val_loss: 0.7937 - val_accuracy: 0.6564
#
# Epoch 00024: val_accuracy did not improve from 0.66639
# Epoch 25/200
# 1085/1085 [==============================] - 31s 29ms/step - loss: 0.7732 - accuracy: 0.6549 - val_loss: 0.7924 - val_accuracy: 0.6481
#
# Epoch 00025: val_accuracy did not improve from 0.66639
# Epoch 26/200
# 1085/1085 [==============================] - 25s 23ms/step - loss: 0.7744 - accuracy: 0.6565 - val_loss: 0.7900 - val_accuracy: 0.6705
#
# Epoch 00026: val_accuracy improved from 0.66639 to 0.67054, saving model to review_sentiment_analysis_model.h5
# Epoch 27/200
# 1085/1085 [==============================] - 25s 23ms/step - loss: 0.7622 - accuracy: 0.6610 - val_loss: 0.7856 - val_accuracy: 0.6664
#
# Epoch 00027: val_accuracy did not improve from 0.67054
# Epoch 28/200
# 1085/1085 [==============================] - 42s 38ms/step - loss: 0.7593 - accuracy: 0.6658 - val_loss: 0.7907 - val_accuracy: 0.6805
#
# Epoch 00028: val_accuracy improved from 0.67054 to 0.68050, saving model to review_sentiment_analysis_model.h5
# Epoch 29/200
# 1085/1085 [==============================] - 32s 30ms/step - loss: 0.7606 - accuracy: 0.6716 - val_loss: 0.7801 - val_accuracy: 0.6564
#
# Epoch 00029: val_accuracy did not improve from 0.68050
# Epoch 30/200
# 1085/1085 [==============================] - 35s 32ms/step - loss: 0.7552 - accuracy: 0.6646 - val_loss: 0.7781 - val_accuracy: 0.6730
#
# Epoch 00030: val_accuracy did not improve from 0.68050
# Epoch 31/200
# 1085/1085 [==============================] - 42s 39ms/step - loss: 0.7469 - accuracy: 0.6786 - val_loss: 0.7831 - val_accuracy: 0.6863
#
# Epoch 00031: val_accuracy improved from 0.68050 to 0.68631, saving model to review_sentiment_analysis_model.h5
# Epoch 32/200
# 1085/1085 [==============================] - 33s 31ms/step - loss: 0.7563 - accuracy: 0.6752 - val_loss: 0.7766 - val_accuracy: 0.6581
#
# Epoch 00032: val_accuracy did not improve from 0.68631
# Epoch 33/200
# 1085/1085 [==============================] - 34s 32ms/step - loss: 0.7416 - accuracy: 0.6842 - val_loss: 0.7780 - val_accuracy: 0.6664
#
# Epoch 00033: val_accuracy did not improve from 0.68631
# Epoch 34/200
# 1085/1085 [==============================] - 40s 37ms/step - loss: 0.7393 - accuracy: 0.6873 - val_loss: 0.7709 - val_accuracy: 0.6838
#
# Epoch 00034: val_accuracy did not improve from 0.68631
# Epoch 35/200
# 1085/1085 [==============================] - 33s 31ms/step - loss: 0.7427 - accuracy: 0.6779 - val_loss: 0.7871 - val_accuracy: 0.6714
#
# Epoch 00035: val_accuracy did not improve from 0.68631
# Epoch 36/200
# 1085/1085 [==============================] - 36s 33ms/step - loss: 0.7365 - accuracy: 0.6836 - val_loss: 0.7663 - val_accuracy: 0.6697
#
# Epoch 00036: val_accuracy did not improve from 0.68631
# Epoch 37/200
# 1085/1085 [==============================] - 42s 39ms/step - loss: 0.7392 - accuracy: 0.6834 - val_loss: 0.7644 - val_accuracy: 0.6855
#
# Epoch 00037: val_accuracy did not improve from 0.68631
# Epoch 38/200
# 1085/1085 [==============================] - 34s 32ms/step - loss: 0.7377 - accuracy: 0.6870 - val_loss: 0.7669 - val_accuracy: 0.6863
#
# Epoch 00038: val_accuracy did not improve from 0.68631
# Epoch 39/200
# 1085/1085 [==============================] - 39s 36ms/step - loss: 0.7190 - accuracy: 0.6927 - val_loss: 0.7659 - val_accuracy: 0.6664
#
# Epoch 00039: val_accuracy did not improve from 0.68631
# Epoch 40/200
# 1085/1085 [==============================] - 38s 35ms/step - loss: 0.7324 - accuracy: 0.6916 - val_loss: 0.7587 - val_accuracy: 0.6838
#
# Epoch 00040: val_accuracy did not improve from 0.68631
# Epoch 41/200
# 1085/1085 [==============================] - 32s 30ms/step - loss: 0.7260 - accuracy: 0.6916 - val_loss: 0.7645 - val_accuracy: 0.6888
#
# Epoch 00041: val_accuracy improved from 0.68631 to 0.68880, saving model to review_sentiment_analysis_model.h5
# Epoch 42/200
# 1085/1085 [==============================] - 42s 39ms/step - loss: 0.7312 - accuracy: 0.6944 - val_loss: 0.7575 - val_accuracy: 0.6739
#
# Epoch 00042: val_accuracy did not improve from 0.68880
# Epoch 43/200
# 1085/1085 [==============================] - 36s 34ms/step - loss: 0.7231 - accuracy: 0.6974 - val_loss: 0.7625 - val_accuracy: 0.6938:  - ETA: 0s - loss: 0.7231 - accura
#
# Epoch 00043: val_accuracy improved from 0.68880 to 0.69378, saving model to review_sentiment_analysis_model.h5
# Epoch 44/200
# 1085/1085 [==============================] - 33s 30ms/step - loss: 0.7217 - accuracy: 0.6929 - val_loss: 0.7663 - val_accuracy: 0.6971
#
# Epoch 00044: val_accuracy improved from 0.69378 to 0.69710, saving model to review_sentiment_analysis_model.h5
# Epoch 45/200
# 1085/1085 [==============================] - 40s 37ms/step - loss: 0.7211 - accuracy: 0.6989 - val_loss: 0.7532 - val_accuracy: 0.6780
#
# Epoch 00045: val_accuracy did not improve from 0.69710
# Epoch 46/200
# 1085/1085 [==============================] - 35s 32ms/step - loss: 0.7100 - accuracy: 0.7043 - val_loss: 0.7521 - val_accuracy: 0.6929
#
# Epoch 00046: val_accuracy did not improve from 0.69710
# Epoch 47/200
# 1085/1085 [==============================] - 37s 34ms/step - loss: 0.7208 - accuracy: 0.6939 - val_loss: 0.7493 - val_accuracy: 0.6913
#
# Epoch 00047: val_accuracy did not improve from 0.69710
# Epoch 48/200
# 1085/1085 [==============================] - 45s 42ms/step - loss: 0.7185 - accuracy: 0.6988 - val_loss: 0.7511 - val_accuracy: 0.6913
#
# Epoch 00048: val_accuracy did not improve from 0.69710
# Epoch 49/200
# 1085/1085 [==============================] - 32s 30ms/step - loss: 0.7160 - accuracy: 0.7008 - val_loss: 0.7577 - val_accuracy: 0.6946
#
# Epoch 00049: val_accuracy did not improve from 0.69710
# Epoch 50/200
# 1085/1085 [==============================] - 39s 36ms/step - loss: 0.7025 - accuracy: 0.7094 - val_loss: 0.7448 - val_accuracy: 0.6938
#
# Epoch 00050: val_accuracy did not improve from 0.69710
# Epoch 51/200
# 1085/1085 [==============================] - 37s 34ms/step - loss: 0.7059 - accuracy: 0.7068 - val_loss: 0.7459 - val_accuracy: 0.6921
#
# Epoch 00051: val_accuracy did not improve from 0.69710
# Epoch 52/200
# 1085/1085 [==============================] - 33s 30ms/step - loss: 0.7078 - accuracy: 0.7005 - val_loss: 0.7506 - val_accuracy: 0.6971
#
# Epoch 00052: val_accuracy did not improve from 0.69710
# Epoch 53/200
# 1085/1085 [==============================] - 41s 37ms/step - loss: 0.6942 - accuracy: 0.7151 - val_loss: 0.7424 - val_accuracy: 0.6963
#
# Epoch 00053: val_accuracy did not improve from 0.69710
# Epoch 54/200
# 1085/1085 [==============================] - 34s 31ms/step - loss: 0.6893 - accuracy: 0.7186 - val_loss: 0.7416 - val_accuracy: 0.6988
#
# Epoch 00054: val_accuracy improved from 0.69710 to 0.69876, saving model to review_sentiment_analysis_model.h5
# Epoch 55/200
# 1085/1085 [==============================] - 34s 31ms/step - loss: 0.7070 - accuracy: 0.7097 - val_loss: 0.7430 - val_accuracy: 0.6946
#
# Epoch 00055: val_accuracy did not improve from 0.69876
# Epoch 56/200
# 1085/1085 [==============================] - 39s 36ms/step - loss: 0.6941 - accuracy: 0.7191 - val_loss: 0.7388 - val_accuracy: 0.6921
#
# Epoch 00056: val_accuracy did not improve from 0.69876
# Epoch 57/200
# 1085/1085 [==============================] - 33s 30ms/step - loss: 0.6916 - accuracy: 0.7204 - val_loss: 0.7607 - val_accuracy: 0.6871
#
# Epoch 00057: val_accuracy did not improve from 0.69876
# Epoch 58/200
# 1085/1085 [==============================] - 33s 31ms/step - loss: 0.7089 - accuracy: 0.7104 - val_loss: 0.7562 - val_accuracy: 0.6996
#
# Epoch 00058: val_accuracy improved from 0.69876 to 0.69959, saving model to review_sentiment_analysis_model.h5
# Epoch 59/200
# 1085/1085 [==============================] - 40s 37ms/step - loss: 0.7030 - accuracy: 0.7077 - val_loss: 0.7422 - val_accuracy: 0.6996
#
# Epoch 00059: val_accuracy did not improve from 0.69959
# Epoch 60/200
# 1085/1085 [==============================] - 32s 29ms/step - loss: 0.6847 - accuracy: 0.7178 - val_loss: 0.7361 - val_accuracy: 0.6921
#
# Epoch 00060: val_accuracy did not improve from 0.69959
# Epoch 61/200
# 1085/1085 [==============================] - 34s 32ms/step - loss: 0.6977 - accuracy: 0.7148 - val_loss: 0.7432 - val_accuracy: 0.7021
#
# Epoch 00061: val_accuracy improved from 0.69959 to 0.70207, saving model to review_sentiment_analysis_model.h5
# Epoch 62/200
# 1085/1085 [==============================] - 38s 35ms/step - loss: 0.6940 - accuracy: 0.7176 - val_loss: 0.7434 - val_accuracy: 0.6988 ETA
#
# Epoch 00062: val_accuracy did not improve from 0.70207
# Epoch 63/200
# 1085/1085 [==============================] - 33s 31ms/step - loss: 0.6883 - accuracy: 0.7146 - val_loss: 0.7357 - val_accuracy: 0.7012
#
# Epoch 00063: val_accuracy did not improve from 0.70207
# Epoch 64/200
# 1085/1085 [==============================] - 38s 35ms/step - loss: 0.6816 - accuracy: 0.7236 - val_loss: 0.7353 - val_accuracy: 0.6988
#
# Epoch 00064: val_accuracy did not improve from 0.70207
# Epoch 65/200
# 1085/1085 [==============================] - 37s 34ms/step - loss: 0.6815 - accuracy: 0.7212 - val_loss: 0.7366 - val_accuracy: 0.7012
#
# Epoch 00065: val_accuracy did not improve from 0.70207
# Epoch 66/200
# 1085/1085 [==============================] - 32s 29ms/step - loss: 0.6910 - accuracy: 0.7216 - val_loss: 0.7373 - val_accuracy: 0.6954
#
# Epoch 00066: val_accuracy did not improve from 0.70207
# Epoch 67/200
# 1085/1085 [==============================] - 39s 36ms/step - loss: 0.6839 - accuracy: 0.7156 - val_loss: 0.7305 - val_accuracy: 0.7046
#
# Epoch 00067: val_accuracy improved from 0.70207 to 0.70456, saving model to review_sentiment_analysis_model.h5
# Epoch 68/200
# 1085/1085 [==============================] - 34s 32ms/step - loss: 0.6840 - accuracy: 0.7211 - val_loss: 0.7309 - val_accuracy: 0.7012
#
# Epoch 00068: val_accuracy did not improve from 0.70456
# Epoch 69/200
# 1085/1085 [==============================] - 34s 31ms/step - loss: 0.6711 - accuracy: 0.7246 - val_loss: 0.7314 - val_accuracy: 0.7029
#
# Epoch 00069: val_accuracy did not improve from 0.70456
# Epoch 70/200
# 1085/1085 [==============================] - 41s 38ms/step - loss: 0.6874 - accuracy: 0.7193 - val_loss: 0.7305 - val_accuracy: 0.7012
#
# Epoch 00070: val_accuracy did not improve from 0.70456
# Epoch 71/200
# 1085/1085 [==============================] - 33s 31ms/step - loss: 0.6843 - accuracy: 0.7282 - val_loss: 0.7458 - val_accuracy: 0.6979
#
# Epoch 00071: val_accuracy did not improve from 0.70456
# Epoch 72/200
# 1085/1085 [==============================] - 35s 33ms/step - loss: 0.6736 - accuracy: 0.7212 - val_loss: 0.7303 - val_accuracy: 0.7037
#
# Epoch 00072: val_accuracy did not improve from 0.70456
# Epoch 73/200
# 1085/1085 [==============================] - 38s 35ms/step - loss: 0.6729 - accuracy: 0.7241 - val_loss: 0.7343 - val_accuracy: 0.7021
#
# Epoch 00073: val_accuracy did not improve from 0.70456
# Epoch 74/200
# 1085/1085 [==============================] - 33s 30ms/step - loss: 0.6760 - accuracy: 0.7296 - val_loss: 0.7311 - val_accuracy: 0.7046
#
# Epoch 00074: val_accuracy did not improve from 0.70456
# Epoch 75/200
# 1085/1085 [==============================] - 37s 34ms/step - loss: 0.6745 - accuracy: 0.7239 - val_loss: 0.7281 - val_accuracy: 0.7029
#
# Epoch 00075: val_accuracy did not improve from 0.70456
# Epoch 76/200
# 1085/1085 [==============================] - 35s 32ms/step - loss: 0.6791 - accuracy: 0.7249 - val_loss: 0.7329 - val_accuracy: 0.7021
#
# Epoch 00076: val_accuracy did not improve from 0.70456
# Epoch 77/200
# 1085/1085 [==============================] - 35s 32ms/step - loss: 0.6835 - accuracy: 0.7243 - val_loss: 0.7267 - val_accuracy: 0.7062
#
# Epoch 00077: val_accuracy improved from 0.70456 to 0.70622, saving model to review_sentiment_analysis_model.h5
# Epoch 78/200
# 1085/1085 [==============================] - 39s 36ms/step - loss: 0.6647 - accuracy: 0.7335 - val_loss: 0.7244 - val_accuracy: 0.7079
#
# Epoch 00078: val_accuracy improved from 0.70622 to 0.70788, saving model to review_sentiment_analysis_model.h5
# Epoch 79/200
# 1085/1085 [==============================] - 32s 30ms/step - loss: 0.6654 - accuracy: 0.7274 - val_loss: 0.7234 - val_accuracy: 0.7054
#
# Epoch 00079: val_accuracy did not improve from 0.70788
# Epoch 80/200
# 1085/1085 [==============================] - 40s 37ms/step - loss: 0.6627 - accuracy: 0.7321 - val_loss: 0.7224 - val_accuracy: 0.7062
#
# Epoch 00080: val_accuracy did not improve from 0.70788
# Epoch 81/200
# 1085/1085 [==============================] - 37s 34ms/step - loss: 0.6598 - accuracy: 0.7308 - val_loss: 0.7234 - val_accuracy: 0.7071
#
# Epoch 00081: val_accuracy did not improve from 0.70788
# Epoch 82/200
# 1085/1085 [==============================] - 36s 33ms/step - loss: 0.6630 - accuracy: 0.7280 - val_loss: 0.7338 - val_accuracy: 0.7012
#
# Epoch 00082: val_accuracy did not improve from 0.70788
# Epoch 83/200
# 1085/1085 [==============================] - 42s 38ms/step - loss: 0.6720 - accuracy: 0.7219 - val_loss: 0.7361 - val_accuracy: 0.7012
#
# Epoch 00083: val_accuracy did not improve from 0.70788
# Epoch 84/200
# 1085/1085 [==============================] - 33s 30ms/step - loss: 0.6521 - accuracy: 0.7337 - val_loss: 0.7268 - val_accuracy: 0.7029
#
# Epoch 00084: val_accuracy did not improve from 0.70788
# Epoch 85/200
# 1085/1085 [==============================] - 38s 35ms/step - loss: 0.6673 - accuracy: 0.7299 - val_loss: 0.7240 - val_accuracy: 0.7037
#
# Epoch 00085: val_accuracy did not improve from 0.70788
# Epoch 00085: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
loaded_model = load_model('review_sentiment_analysis_model.h5')
print("Test Accuracy: {:.4f}%".format(loaded_model.evaluate(x_test, y_test)[1]*100))
# Out:
# 95/95 [==============================] - 2s 16ms/step - loss: 0.7085 - accuracy: 0.7009
# Test Accuracy: 70.0922%
